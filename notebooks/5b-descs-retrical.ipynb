# %% [markdown]
# # Retrival
#
# Für die Beschreibungen gibt es ein eigenes Retrival-Notebook damit das erste nicht zu lange wird. Prinzipiell ist es das Selbe, hauptsächlich unterschiedlich in der Evaluation und beim Reranking.
